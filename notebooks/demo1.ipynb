# %%
using Gershgorin

# %%
using Plots

# Make a random (5,5) complex matrix
M = randn(ComplexF32, 5, 5)

gershgorin(M; c=:blue, label="M") |> display
savefig("gershgorin_M.png")
gershgorin(M'; c=:red, label="M'") |> display
savefig("gershgorin_M_transpose.png")
